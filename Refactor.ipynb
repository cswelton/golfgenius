# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os
from selenium.webdriver.firefox.options import Options as FirefoxOptions
import itertools
import time
import re
import logging
import json
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
class Parser(object):
    def __init__(self, driver):
        self.driver = driver

    def _get_element(self, e):
        xpath = self.xpath_soup(e)
        return self.driver.find_element_by_xpath(xpath)
    
    def xpath_soup(self, element):
        components = []
        child = element if element.name else element.parent
        for parent in child.parents:
            """
            @type parent: bs4.element.Tag
            """
            previous = itertools.islice(parent.children, 0, parent.contents.index(child))
            xpath_tag = child.name
            xpath_index = sum(1 for i in previous if i.name == xpath_tag) + 1
            components.append(xpath_tag if xpath_index == 1 else '%s[%d]' % (xpath_tag, xpath_index))
            child = parent
        components.reverse()
        return '/%s' % '/'.join(components)
    
    @property
    def soup(self):
        return BeautifulSoup(self.driver.page_source, "html.parser")

# %%
def create_driver():
    options = FirefoxOptions()
    driver = webdriver.Firefox(
        service_log_path=os.path.devnull,
        options=options,
        executable_path=os.path.join(
            "golfgenius", "drivers", "firefox", "0.28", "geckodriver"))
    driver.set_window_size(1920, 1080)
    return driver

def sign_in(parser, ggid="nzxmej"):
    parser.driver.get("https://www.golfgenius.com/golfgenius")
    time.sleep(2)
    login_button = parser._get_element(parser.soup.find('a', text='SIGN IN'))
    login_button.click()
    time.sleep(1)
    ggid_input = parser._get_element(parser.soup.find('input', {u"placeholder": u"Enter Your GGID", u"type": u"text"}))
    ggid_input.clear()
    ggid_input.send_keys(ggid)
    sign_in_button = parser._get_element(parser.soup.find('input', type="submit", value="Sign In"))
    sign_in_button.click()
    time.sleep(5)
    sign_in_button2 = parser._get_element(parser.soup.find('input', type="submit", value="Sign In"))
    sign_in_button2.click()

# %%
d = Parser(create_driver())

# %%
results_page = "https://www.golfgenius.com/leagues/7021866105153037134/widgets/tournament_results"
d.driver.get(results_page)
regex = re.compile('\/v2tournaments\/(\d+)')
links = []
for o in d.soup.find(id='round').find_all('option'):
    d._get_element(o).click()
    WebDriverWait(d.driver, 15).until(
        EC.visibility_of_element_located(
        (By.XPATH, "//a[@class='expand-tournament']")))
    for l in d.soup.find_all('a', {"class": "expand-tournament", "data-tournament-spec-id": True}):
        eid = regex.search(l.attrs["href"]).group(1)
        links.append("https://www.golfgenius.com/tournaments2/details?adjusting=false&event_id=%s" % eid)

results = []
for l in links:
    d.driver.get(l)
    WebDriverWait(d.driver, 15).until(
            EC.visibility_of_element_located(
                (By.XPATH, "//table[@class='scorecard']")))
    table = d.soup.find('table', {"class": "scorecard"})
    teams = [[x.strip() for x in tr.attrs["data-aggregate-name"].split("+")] for tr in table.find_all("tr", {"class": "aggregate_score", "data-aggregate-name": True})]
    results.append({"table": table, "teams": teams})

# %%
# sync_golfgenius
import logging
import re
import json
import argparse
import os
from golfgenius.parser import GGParser


logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
stream = logging.StreamHandler()
stream.setLevel(logging.INFO)
logger.addHandler(stream)
parser = GGParser(headless=False, screenshots_enabled=False)
rounds = list(parser.iter_rounds("nzxmej", filter=re.compile(".*April.*")))
# Out:
# Loading landing page https://www.golfgenius.com/leagues/7021866105153037134/widgets/tournament_results
# Locating round Round 27 (Fri, April 16)..
# Locating round Round 26 (Sun, April 11)..
# Locating round Round 25 (Fri, April  9)..
# Locating round Round 24 (Fri, April  2)..
# Skipping round Round 23 (Tue, March 30), does not match pattern .*April.*
# Skipping round Round 22 (Fri, March 26), does not match pattern .*April.*
# Skipping round Round 21 (Wed, March 24), does not match pattern .*April.*
# Skipping round Round 20 (Fri, March 12), does not match pattern .*April.*
# Skipping round Round 17 (Tue, March  9), does not match pattern .*April.*
# Skipping round Round 16 (Sun, March  7), does not match pattern .*April.*
# Skipping round Round 15 (Fri, March  5), does not match pattern .*April.*
# Skipping round Round 14 (Thu, March  4), does not match pattern .*April.*
# Skipping round Round 13 (Sun, February 28), does not match pattern .*April.*
# Skipping round Round 12 (Thu, February 25), does not match pattern .*April.*
# Skipping round Round 11 (Wed, February 24), does not match pattern .*April.*
# Skipping round Round 10 (Sat, February  6), does not match pattern .*April.*
# Skipping round Round 9 (Fri, February  5), does not match pattern .*April.*
# Skipping round Round 8 (Thu, February  4), does not match pattern .*April.*
# Skipping round Round 7 (Fri, January 29), does not match pattern .*April.*
# Skipping round Round 6 (Fri, January 22), does not match pattern .*April.*
# Skipping round Round 5 (Fri, January 15), does not match pattern .*April.*
# Skipping round Round 4 (Thu, January 14), does not match pattern .*April.*
# Skipping round Round 3 (Wed, January 13), does not match pattern .*April.*
# Skipping round Round 2 (Sun, January 10), does not match pattern .*April.*
# Pulling data for 4 rounds
# Data pulled for 4 rounds

# %%
rounds[0][1]["results"]
# Out:
# {'teams': [['Hilliard, Tj',
#    'McDougald, Kevin',
#    'Roberts, Evan',
#    'Corcoran, Scott'],
#   ['Fish, Tony', 'Long, Glen', 'Beaird, Ray', 'Howard, Matt'],
#   ['Perry, Robbie', 'Welton, Craig', 'Capwell, Robert', 'Zogby, Kevin']],
#  'scores': {'Hilliard, Tj': {'scores': {'1': {'score': 4, 'type': 'birdie'},
#     '2': {'score': 5, 'type': 'plus1'},
#     '3': {'score': 2, 'type': 'birdie'},
#     '4': {'score': 3, 'type': 'birdie'},
#     '5': {'score': 4, 'type': 'birdie'},
#     '6': {'score': 6, 'type': 'plus2'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 3, 'type': 'birdie'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 5, 'type': 'plus1'},
#     '14': {'score': 6, 'type': 'plus1'},
#     '15': {'score': 2, 'type': 'birdie'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 4, 'type': 'par'}}},
#   'McDougald, Kevin': {'scores': {'1': {'score': 5, 'type': 'par'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 3, 'type': 'birdie'},
#     '8': {'score': 4, 'type': 'plus1'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 5, 'type': 'plus1'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 5, 'type': 'plus1'},
#     '18': {'score': 3, 'type': 'birdie'}}},
#   'Roberts, Evan': {'scores': {'1': {'score': 5, 'type': 'par'},
#     '2': {'score': 5, 'type': 'plus1'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 5, 'type': 'plus1'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 7, 'type': 'plus2'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 5, 'type': 'plus1'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 6, 'type': 'plus1'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 3, 'type': 'birdie'},
#     '17': {'score': 3, 'type': 'birdie'},
#     '18': {'score': 4, 'type': 'par'}}},
#   'Corcoran, Scott': {'scores': {'1': {'score': 6, 'type': 'plus1'},
#     '2': {'score': 3, 'type': 'birdie'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 5, 'type': 'plus1'},
#     '5': {'score': 4, 'type': 'birdie'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 2, 'type': 'birdie'},
#     '12': {'score': 5, 'type': 'plus1'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 6, 'type': 'plus1'},
#     '15': {'score': 2, 'type': 'birdie'},
#     '16': {'score': 5, 'type': 'plus1'},
#     '17': {'score': 3, 'type': 'birdie'},
#     '18': {'score': 3, 'type': 'birdie'}}},
#   'Fish, Tony': {'scores': {'1': {'score': 4, 'type': 'birdie'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 3, 'type': 'par'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 2, 'type': 'birdie'},
#     '12': {'score': 3, 'type': 'birdie'},
#     '13': {'score': 3, 'type': 'birdie'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 5, 'type': 'plus1'}}},
#   'Long, Glen': {'scores': {'1': {'score': 5, 'type': 'par'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 3, 'type': 'par'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 5, 'type': 'plus1'},
#     '7': {'score': 6, 'type': 'plus2'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 6, 'type': 'plus2'},
#     '10': {'score': 6, 'type': 'plus1'},
#     '11': {'score': 4, 'type': 'plus1'},
#     '12': {'score': 5, 'type': 'plus1'},
#     '13': {'score': 5, 'type': 'plus1'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 4, 'type': 'plus1'},
#     '16': {'score': 5, 'type': 'plus1'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 5, 'type': 'plus1'}}},
#   'Beaird, Ray': {'scores': {'1': {'score': 4, 'type': 'birdie'},
#     '2': {'score': 3, 'type': 'birdie'},
#     '3': {'score': 2, 'type': 'birdie'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 4, 'type': 'birdie'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 6, 'type': 'plus1'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 4, 'type': 'par'}}},
#   'Howard, Matt': {'scores': {'1': {'score': 5, 'type': 'par'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 7, 'type': 'plus2'},
#     '6': {'score': 5, 'type': 'plus1'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 5, 'type': 'plus2'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 6, 'type': 'plus1'},
#     '11': {'score': 4, 'type': 'plus1'},
#     '12': {'score': 5, 'type': 'plus1'},
#     '13': {'score': 5, 'type': 'plus1'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 5, 'type': 'plus1'},
#     '17': {'score': 6, 'type': 'plus2'},
#     '18': {'score': 5, 'type': 'plus1'}}},
#   'Perry, Robbie': {'scores': {'1': {'score': 6, 'type': 'plus1'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 2, 'type': 'birdie'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 4, 'type': 'plus1'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 4, 'type': 'par'}}},
#   'Welton, Craig': {'scores': {'1': {'score': 4, 'type': 'birdie'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 4, 'type': 'par'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 6, 'type': 'plus1'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 4, 'type': 'birdie'},
#     '15': {'score': 2, 'type': 'birdie'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 5, 'type': 'plus1'}}},
#   'Capwell, Robert': {'scores': {'1': {'score': 7, 'type': 'plus2'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 3, 'type': 'par'},
#     '4': {'score': 5, 'type': 'plus1'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 5, 'type': 'plus1'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 4, 'type': 'par'},
#     '10': {'score': 6, 'type': 'plus1'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 6, 'type': 'plus2'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 4, 'type': 'birdie'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 6, 'type': 'plus2'}}},
#   'Zogby, Kevin': {'scores': {'1': {'score': 6, 'type': 'plus1'},
#     '2': {'score': 4, 'type': 'par'},
#     '3': {'score': 4, 'type': 'plus1'},
#     '4': {'score': 4, 'type': 'par'},
#     '5': {'score': 5, 'type': 'par'},
#     '6': {'score': 5, 'type': 'plus1'},
#     '7': {'score': 4, 'type': 'par'},
#     '8': {'score': 3, 'type': 'par'},
#     '9': {'score': 5, 'type': 'plus1'},
#     '10': {'score': 5, 'type': 'par'},
#     '11': {'score': 3, 'type': 'par'},
#     '12': {'score': 4, 'type': 'par'},
#     '13': {'score': 4, 'type': 'par'},
#     '14': {'score': 5, 'type': 'par'},
#     '15': {'score': 3, 'type': 'par'},
#     '16': {'score': 4, 'type': 'par'},
#     '17': {'score': 4, 'type': 'par'},
#     '18': {'score': 4, 'type': 'par'}}}}}

# %%
    
def get_teams_and_tables(option, element):
    results = {}
    round_name, round_id = option.text.strip(), option.attrs["value"]
    results['round_name'] = round_name
    results['round_id'] = round_id
    results['tournaments'] = []
    element.click()
    tournament_links = ["https://www.golfgenius.com" + t.attrs["href"] for t in d.soup.find_all('a', {"class": "expand-tournament", "data-tournament-spec-id": True})]
    for link in tournament_links:
        d.driver.get(link)
        WebDriverWait(
            d.driver, 10).until(EC.visibility_of_element_located(
            (By.XPATH, "//a[@class='expand-all']")))
        d._get_element(d.soup.find('a', {"class": "expand-all"})).click()
        WebDriverWait(d.driver, 15).until(
            EC.visibility_of_element_located(
                (By.XPATH, "//table[@class='scorecard']")))
        table = d.soup.find('table', {"class": "scorecard"})
        teams = [[x.strip() for x in tr.attrs["data-aggregate-name"].split("+")] for tr in table.find_all("tr", {"class": "aggregate_score", "data-aggregate-name": True})]
        results['tournaments'].append({"teams": teams, "table": table})
    return results
    
    #tournaments = d.soup.find_all('a', {"class": "expand-tournament", "data-tournament-spec-id": True})
    #for tournament in tournaments:
    #    print("https://www.golfgenius.com" + tournament.attrs["href"])
    #    t_id = tournament.attrs["data-tournament-event-id"]
    #    d._get_element(tournament).click()
    #    WebDriverWait(
    #        d.driver, 10).until(EC.visibility_of_element_located(
    #            (By.XPATH, "//a[@class='expand-all']")))
    #    d._get_element(d.soup.find('a', {"class": "expand-all"})).click()
    #    WebDriverWait(d.driver, 15).until(
    #        EC.visibility_of_element_located(
    #            (By.XPATH, "//table[@class='scorecard']")))
    #    table = d.soup.find('table', {"class": "scorecard"})
    #    teams = [[x.strip() for x in tr.attrs["data-aggregate-name"].split("+")] for tr in table.find_all("tr", {"class": "aggregate_score", "data-aggregate-name": True})]
    #    results['tournaments'].append({"teams": teams, "table": table})
    #    d._get_element(d.soup.find('a', {"class": "collapse-all", "data-event-id": t_id})).click()
    #    WebDriverWait(
    #        d.driver, 10).until(EC.element_to_be_clickable(
    #            (By.XPATH, "//a[@class='expand-all']")))
    #    d._get_element(tournament).click()
    #    time.sleep(1.5)
    #return results

# %%
def get_rounds(d):
    results_link = d.soup.find('a', text=re.compile(r"\s*Results\s*"))
    d._get_element(results_link).click()
    time.sleep(2)
    d.soup.find('iframe', {"name": "page_iframe"}).attrs["src"]
    d.driver.switch_to.frame("page_iframe")
    round_options = d.soup.find(id='round').find_all('option')
    items = []
    for o in round_options:
        items.append((o, d._get_element(o)))
    
    results = []
    for option, element in items:
        print(option.text.strip(), option.attrs)
        results.append(get_teams_and_tables(option, element))
    return results

# %%
results = get_rounds(d)
# Out:
# Round 26 (Sun, April 11) {'selected': 'selected', 'value': '7319983582422803361'}
# Round 25 (Fri, April  9) {'value': '7314458308088210270'}
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-8-d63ea7f8ad28> in <module>
# ----> 1 results = get_rounds(d)
#
# <ipython-input-7-34536cec36df> in get_rounds(d)
#      13     for option, element in items:
#      14         print(option.text.strip(), option.attrs)
# ---> 15         results.append(get_teams_and_tables(option, element))
#      16     return results
#
# <ipython-input-6-02dc6dbfc051> in get_teams_and_tables(option, element)
#       5     results['round_id'] = round_id
#       6     results['tournaments'] = []
# ----> 7     element.click()
#       8     tournament_links = ["https://www.golfgenius.com" + t.attrs["href"] for t in d.soup.find_all('a', {"class": "expand-tournament", "data-tournament-spec-id": True})]
#       9     for link in tournament_links:
#
# ~/virtualenv/golfgenius/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/virtualenv/golfgenius/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/virtualenv/golfgenius/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/virtualenv/golfgenius/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: The element reference of <option> is stale; either the element is no longer attached to the DOM, it is not in the current frame context, or the document has been refreshed

# %%
d.driver.get(links[0])
WebDriverWait(d.driver, 15).until(
            EC.visibility_of_element_located(
                (By.XPATH, "//table[@class='scorecard']")))
table = d.soup.find('table', {"class": "scorecard"})
teams = [[x.strip() for x in tr.attrs["data-aggregate-name"].split("+")] for tr in table.find_all("tr", {"class": "aggregate_score", "data-aggregate-name": True})]

# %%
teams
# Out:
# [['Alford, Sumner', 'Fish, Tony', 'Welton, Craig', 'Zogby, Kevin'],
#  ['Smith, Brian', 'Samuel, Matthew', 'Beaird, Ray', 'Stefanacci, Michael'],
#  ['Perry, Robbie', 'Whartenby, Robert', 'Capwell, Robert', 'Shoffner, Chris']]

# %%
import re
regex = re.compile('\/v2tournaments\/(\d+)')
regex.search(links[0]).group(1)
# Out:
# '7319983677415400015'

# %%
d.soup.find_all('a', {"class": "expand-tournament", "data-tournament-spec-id": True})
# Out:
# [<a class="expand-tournament" data-remote="true" data-tournament-event-id="7319983677415400015" data-tournament-spec-id="7319983601280394076" href="/v2tournaments/7319983677415400015?round_index=26">Two Best Ball Front
#  </a>,
#  <a class="expand-tournament" data-remote="true" data-tournament-event-id="7319983694024843856" data-tournament-spec-id="7319983618695144285" href="/v2tournaments/7319983694024843856?round_index=26">Two Best Ball Back
#  </a>,
#  <a class="expand-tournament" data-remote="true" data-tournament-event-id="7319983698856682065" data-tournament-spec-id="7319983625573802846" href="/v2tournaments/7319983698856682065?round_index=26">Two Best Ball Overall
#  </a>,
#  <a class="expand-tournament" data-remote="true" data-tournament-event-id="7319983699225780818" data-tournament-spec-id="7319983632687342431" href="/v2tournaments/7319983699225780818?round_index=26">Individual Skins
#  </a>]

# %%
d.soup.find(id='round').find_all('option')
# Out:
# [<option selected="selected" value="7319983582422803361">Round 26 (Sun, April 11)</option>,
#  <option value="7314458308088210270">Round 25 (Fri, April  9)</option>,
#  <option value="7294138215475225239">Round 24 (Fri, April  2)</option>,
#  <option value="7285571483303191080">Round 23 (Tue, March 30)</option>,
#  <option value="7273395674543072110">Round 22 (Fri, March 26)</option>,
#  <option value="7268048562833892177">Round 21 (Wed, March 24)</option>,
#  <option value="7224730243670516250">Round 20 (Fri, March 12)</option>,
#  <option value="7224730084958052887">Round 17 (Tue, March  9)</option>,
#  <option value="7218556708849755121">Round 16 (Sun, March  7)</option>,
#  <option value="7210116988792775655">Round 15 (Fri, March  5)</option>,
#  <option value="7210116900846609382">Round 14 (Thu, March  4)</option>,
#  <option value="7198509549899260679">Round 13 (Sun, February 28)</option>,
#  <option value="7186573493494915771">Round 12 (Thu, February 25)</option>,
#  <option value="7186573446753591994">Round 11 (Wed, February 24)</option>,
#  <option value="7134351588881113692">Round 10 (Sat, February  6)</option>,
#  <option value="7132006465904091717">Round 9 (Fri, February  5)</option>,
#  <option value="7128648205675307544">Round 8 (Thu, February  4)</option>,
#  <option value="7070731751999447973">Round 7 (Fri, January 29)</option>,
#  <option value="7070731707103617956">Round 6 (Fri, January 22)</option>,
#  <option value="7070731649926865827">Round 5 (Fri, January 15)</option>,
#  <option value="7068110707572646796">Round 4 (Thu, January 14)</option>,
#  <option value="7064899107726336843">Round 3 (Wed, January 13)</option>,
#  <option value="7056486185245385506">Round 2 (Sun, January 10)</option>]
